# %%
import whois
import pandas as pd
import tldextract
import datetime

# %%
df= pd.read_csv("final_dataset.csv")

# %%
df.head(10)
# Out:
#                                                  url  label
# 0                      http://www.currysleather.com/      0
# 1                             http://www.mcfc.co.uk/      0
# 2  https://whatsapp.blazagency.com/99e665748bd5bf...      1
# 3                       https://pwcs-co.cf/?login=do      1
# 4               https://messagerie-llebon-coins.com/      1
# 5         http://www.mclink.it/assoc/isp/fineng.html      0
# 6  https://nervousstudentllama.tumblr.com/ARU?id=...      1
# 7     http://royalmail.reschedule-missed-parcel.com/      1
# 8                         http://www.britishtea.com/      0
# 9                          http://www.mon-photo.com/      0

# %%
len(df)
# Out:
# 6988

# %%
feature_set = pd.DataFrame(columns=('url', 'duration', 'label'))

# %%
def get_features(url , label):
    result = []
    url = str(url)
    result.append(url)
    # url = "http://royalmail.reschedule-missed-parcel.com/"
    ext = tldextract.extract(url)
    domain = '.'.join(ext[1:])
    
    try:
        whois.query(domain)
    except:
        result.append('-1')
        result.append(str(label))
        return result
    else:
        w = whois.query(domain)
    
    if w is None:
        return result
    
    avg_month_time=365.2425/12.0
    
    #calculate creation age in months
    
    create_date = -1
    if w.creation_date == None or type(w.creation_date) is str :
        create_date = -1
    else:
        if(type(w.creation_date) is list): 
            create_date=w.creation_date[-1]
        else:
            create_date=w.creation_date
    
    #calculate expiry age in months
    
    expiry_date = -1
    if(w.expiration_date==None or type(w.expiration_date) is str):
        expiry_date = -1
    else:
        if(type(w.expiration_date) is list):
            expiry_date=w.expiration_date[-1]
        else:
            expiry_date=w.expiration_date

    if create_date == -1 or expiry_date == -1:
        result.append('-1')
    else:
        duration = round(((expiry_date - create_date).days)/avg_month_time)
        result.append(str(duration))
    result.append(str(label))
    return result

# %%
for i in range(len(df)):
    features = get_features(df["url"].loc[i], df["label"].loc[i]) 
    if(len(features) == 3):
        print(features)
        feature_set.loc[i] = features
#     feature_set.loc[i] = features
    if i%100 == 0:
        print(len(feature_set.index))
print(feature_set.head())
print(len(feature_set.index))
# Out:
# ['http://www.currysleather.com/', '240', '0']
# 1
# ['http://www.mcfc.co.uk/', '309', '0']
# ['https://whatsapp.blazagency.com/99e665748bd5bf84e697ae5e154f1baa/', '12', '1']
# ['https://pwcs-co.cf/?login=do', '-1', '1']
# ['https://messagerie-llebon-coins.com/', '12', '1']
# ['http://www.mclink.it/assoc/isp/fineng.html', '266', '0']
# ['https://nervousstudentllama.tumblr.com/ARU?id=/Amail3bef69ff484881f9d588a4d4a3026b61Asmail', '204', '1']
# ['http://royalmail.reschedule-missed-parcel.com/', '12', '1']
# ['http://www.britishtea.com/', '288', '0']
# ['http://www.mon-photo.com/', '204', '0']
# ['http://monthly-o2-paymentsupport.com/', '12', '1']
# ['https://oqskjhpgpczegrzqtsfuvyxcul-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['http://www.pencildude.com/', '252', '0']
# ['https://greennepal.org/Tax%20Returns%20review/index.php?mail=foo@example.com', '60', '1']
# ['http://rni.nic.in/', '204', '0']
# ['https://httpsloginorangefr60.yolasite.com/', '156', '1']
# ['https://www.o2.solution-verify.com/Login/index?id=e2ab64dd2fe207eb602a612482b3c06ee2ab64dd2fe207eb602a612482b3c06e&amp;session=e2ab64dd2fe207eb602a612482b3c06ee2ab64dd2fe207eb602a612482b3c06e', '12', '1']
# ['http://www.instagram.vintweb.ir/login.html', '-1', '1']
# ['http://www.soccerbase.com/teams/team.sd?team_id=1724', '276', '0']
# ['http://www.plantlife.net/', '276', '0']
# ['http://www.isis.org/', '324', '0']
# ['http://savoyfoods.com/', '184', '0']
# ['http://www.perlier.com/', '252', '0']
# ['https://aagiineqxbcmnkdnceowacqnpi-dot-gle39404049.rj.r.appspot.com/#andy.coles@aviva.com', '204', '1']
# ['https://myaib-account.com/Login.php', '12', '1']
# ['https://plpg.com.au/access/wells/wells.htm', '-1', '1']
# ['http://www.bmsbusinesscentre.com/', '228', '0']
# ['http://www.woodenwinebox.co.uk/', '240', '0']
# ['http://www.gameconfig.co.uk/', '216', '0']
# ['http://www.americanlibraryinparis.org/', '252', '0']
# ['http://www.bruceclay.com/searchenginechart.pdf', '300', '0']
# ['http://www.careersbychoice.com/', '241', '0']
# ['http://arxiv.org/', '372', '0']
# ['http://www.soygold.com/', '336', '0']
# ['http://lockhartchisholmtrailbbq.com/', '72', '0']
# ['http://dbs.vote-friend.com/sg?ref=anything', '12', '1']
# ['http://aromatic.webenliven.in/wp-admin/css/trust/sun/cd.php?_christophin=login_submit&id=', '48', '1']
# ['http://agnix.sourceforge.net/', '300', '0']
# ['http://www.mercedes-benz.com/', '420', '0']
# ['http://royalmail.redeliver-missed-parcel.com/', '12', '1']
# ['http://www.marltoncoffee.com/', '192', '0']
# ['http://www.hsbc.authorise-prevent.com/Login.php', '12', '1']
# ['http://instagram-x.ru/login', '12', '1']
# ['http://www.nhm-wien.ac.at/', '-1', '0']
# ['https://fwcfmuzsowlibaupgfvxgajamk-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['http://mail.tsay017.c0dashop.com/', '12', '1']
# ['http://www.settlersindia.com/', '276', '0']
# ['http://www.rosettis.com/', '264', '0']
# ['http://www.kungfu.cc/kf_list.shtml', '338', '0']
# ['http://www.gbslinens.com/', '276', '0']
# ['http://www.abcfeelings.com/', '277', '0']
# ['https://sqairqessehilunlzweccacaih-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['https://itkrduskavqysizkizuahecmau-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['https://jcb-co-jp-iss-mobile-open-ewsb.top/?page=login', '-1', '1']
# ['https://dierct-cuenta-online.com/A/r4/index.php', '12', '1']
# ['http://in.jobsdb.com/IN', '276', '0']
# ['http://www.umbrellaclubla.com/8sf7f57sf687a68sf68dg78d88sf6f7fsfg3dg24gd235dg7hh87hd6g6d6fh7h6fh/Log%20in%20_%20WeTransfer.php', '96', '1']
# ['http://shastrifc.com/', '12', '0']
# ['http://www.horstheld.com/', '276', '0']
# ['http://www.abcr.de/', '-1', '0']
# ['http://bedfordwines.com/', '300', '0']
# ['https://www.cia.gov/library/publications/world-leaders-1/IN.html', '-1', '0']
# ['http://www.thinkingblocks.com/ThinkingBlocks_AS/TB_AS_Main.html', '192', '0']
# ['http://www.naturismfitz.com/', '180', '0']
# ['http://www.nicebradnlook.tonohost.com/', '36', '1']
# ['https://www.lloysecauth.com/Login.php', '12', '1']
# ['http://touring-india.chez-alice.fr/', '156', '0']
# ['http://www.dfwvases.com/', '168', '0']
# ['http://www.crystal-sets.com/', '12', '0']
# ['https://paypial-us.com/', '12', '1']
# ['https://rblxapiv7.000webhostapp.com/', '72', '1']
# ['https://dvyqrabdukziycbjrstaumjvtr-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['https://resecured-mypayees.com/Login.php', '12', '1']
# ['http://www.grapeswine.com/', '264', '0']
# ['https://ee-billing-home.com/', '12', '1']
# ['http://www.professionalresumes.com.au/', '-1', '0']
# ['http://www.meetapandit.com/', '240', '0']
# ['https://mail.arigo.ng/.well-known/tracking-ch/login/index.php?trackid=CS471210241DE', '-1', '1']
# ['http://www.primeaumusic.com/', '324', '0']
# ['http://kopral-jono-giveaway-akun.duckdns.org/', '192', '1']
# ['http://www.bio.davidson.edu/courses/genomics/mirror/Urchin/u0maps.htm', '362', '0']
# ['http://www.marketwire.com/', '288', '0']
# ['https://oroma-42f59.web.app/rabo/inloggen.php', '-1', '1']
# ['http://dst.gujarat.gov.in/', '216', '0']
# ['http://ovaismirza-politicalthoughts.blogspot.com/', '252', '0']
# ['http://suspfacebookcom-81448794.nightaway.ca/connect.html?timelimit=eb0a9edccea90e37ea7c82e460ec1416', '48', '1']
# ['http://www.dicolympic.com/', '48', '0']
# ['http://www.journals.elsevier.com/biophysical-chemistry/', '336', '0']
# ['https://royalmail-packageformfee.com/verifylogin.php?&amp;sessionid=$hash&amp;securessl=true', '12', '1']
# ['https://www.lloydbank-deviceaccess.com/Login.php', '12', '1']
# ['http://main.d1o5w2cgv976pr.amplifyapp.com/', '36', '1']
# ['https://www.secure-payee-review.net/Login.php', '12', '1']
# ['http://www.sugarboo.com/', '276', '0']
# ['http://njjcsqfzckliiuewjgrejgzuna-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['http://www.bindass.com/', '228', '0']
# ['https://royalmail-reschedulepackage.com/verifylogin.php?&amp;sessionid=$hash&amp;securessl=true', '12', '1']
# ['http://www.sevencups.com/', '228', '0']
# ['http://www.paper-clip.com/', '384', '0']
# ['https://accesoclientesservices.com/b/acceso-clientes/', '12', '1']
# 99
# ['http://www.sinotradenet.com/', '276', '0']
# ['https://flatwaredawn.com/uc/', '12', '1']
# ['http://www.recordandtapetraders.com/', '276', '0']
# ['http://www.flashq.org/', '228', '0']
# ['http://www.cardno.info/', '216', '0']
# ['https://pichincha-security.com/pichi.html', '12', '1']
# ['https://htxcleaning.com/Proposal/Proposal', '24', '1']
# ['https://www.royalmail-secureparcel.com/secure.php?&amp;sessionid=$hash&amp;securessl=true', '12', '1']
# ['https://royalmail.support-helpuk.com/secure.php?&amp;sessionid=$hash&amp;securessl=true', '12', '1']
# ['http://143.92.51.124/ap/signin?key=a@b.c', '-1', '1']
# ['http://scitation.aip.org/content/aip/magazine/physicstoday', '396', '0']
# ['http://www.neuron.co.uk/', '324', '0']
# ['http://top-solcasino.club/', '12', '1']
# ['http://sound.jp/strangelove/', '-1', '0']
# ['https://roxcasinos.ew.r.appspot.com', '204', '1']
# ['http://en.wikipedia.org/wiki/Hillsborough_disaster', '264', '0']
# ['http://www.moscowrenfair.org/', '264', '0']
# ['http://omesqiwines.de/Amazon/931f7664fffbe94f27a09562eb226473/information.php', '-1', '1']
# ['http://www.afloral.com/', '288', '0']
# ['https://www.support-verify-newtransfers.com/Login.php', '12', '1']
# ['http://www.perfumecenter.com/', '288', '0']
# ['http://sugardannys.com/', '12', '0']
# ['http://www.resumeprose.com/', '240', '0']
# ['http://www.ingeborgs.com/', '336', '0']
# ['http://artilect.org/', '264', '0']
# ['http://safetyguard-001-site1.itempurl.com/help.htm', '96', '1']
# ['http://www.portwine.com/', '252', '0']
# ['https://pemblokiran-facbook.duckdns.org/', '192', '1']
# ['https://zhbqionotmprqtefeaawgeoara-dot-glmar9393293232323.uk.r.appspot.com/', '204', '1']
# ['https://s.id/oiuyyu88766556', '96', '1']
# ['https://www.royalmail-onway.com/verifylogin.php?&amp;sessionid=$hash&amp;securessl=true', '12', '1']
# ['https://qlymwdrkqugrpnxsxpwupxcmch-dot-glmar9393293232323.uk.r.appspot.com/', '204', '1']
# ['http://www.sit.edu/graduate/contact-program.cfm', '308', '0']
# ['http://www.ambergallery.lt/', '36', '0']
# ['http://www.davis-inc.com/rmftl', '312', '0']
# ['http://btcommunicationbusiness.weebly.com/', '192', '1']
# ['http://zfskdnhnzmegbpxnljnhuspleu-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['https://royalmail-unpaid-shipping-fee.com/banks/online.citi.eu/', '12', '1']
# ['https://andinabeer.com/d.php', '12', '1']
# ['http://www.quanlichem.com/', '-1', '0']
# ['https://smart2host.com/45454/next.php?ss=2&amp;email=YWNjb3VudHNwYXlhYmxlQGdjZ2FtaW5nLmNvbQ==', '60', '1']
# ['http://clarkdd.tk/?login=do', '-1', '1']
# ['http://www.alertedpayeeinfo.com/lloyds/', '12', '1']
# ['https://drshimashadman.ir/', '-1', '1']
# ['http://www.dvdwb.com/', '312', '0']
# ['http://www.algolia.com/', '144', '0']
# ['http://www.cut-the-knot.org/ctk/August2001.shtml', '240', '0']
# ['http://www.brighter.com.hk/', '-1', '0']
# ['https://www.micard.co.jp.rkfcw.com/', '36', '1']
# ['https://skandasmk-colmek8.mydad.info/login.php', '240', '1']
# ['http://www.kingpelican.com/', '228', '0']
# ['http://www.octave.org/', '264', '0']
# ['http://www.numerical-methods.com/', '264', '0']
# ['https://olx.pl-sprzedaz.shop/login/ipko/?id=633b8c37ea574636d273dee41f36e2aa', '-1', '1']
# ['http://www.onlinehelp-uk.com/', '48', '0']
# ['http://dev.klinikmatanusantara.com/log-au/mpp/signin/0d64/websrc', '252', '1']
# ['http://www.vibranture.com/', '240', '0']
# ['http://mamet.eserver.org/', '300', '0']
# ['https://micmsnout.weebly.com/', '192', '1']
# ['http://dev.klinikmatanusantara.com/log-au/mpp/signin/00b8/websrc', '252', '1']
# ['https://www.sparkassen-giroverband10.xyz/sp/anmeldung.php?starten=4IDofT0ENeU58KuhlgvtGVyXSHcMwC&amp;shufflUri?=KMt0c5IiNG6LUhuYAgFo', '12', '1']
# ['http://www.teteas.com/', '288', '0']
# ['https://www1.smbe-card.zdhdq.cn/404.html', '12', '1']
# ['http://northcountyluxuryrealestate.com/Lunosaisd/LUNO_2021/', '60', '1']
# ['https://facabook.in/', '12', '1']
# ['http://canal-nantes-brest.fr/-/orange/f0d91/index2.html', '12', '1']
# ['http://www.canal-nantes-brest.fr/-/orange/435ca', '12', '1']
# ['https://xn--www-bmobnking-pf2g.com/page1.php', '12', '1']
# ['https://ib2-security.com/att/classic/mobile/home.php', '12', '1']
# ['http://bolicarp.com/chase/chase.com-RD148-simple-finish/', '12', '1']
# ['https://mps-acceso.com/accedi/', '12', '1']
# ['http://www.manorresources.co.uk/', '264', '0']
# ['https://www.amiozan.co-jp-azmiazmoznozanm.buzz/', '-1', '1']
# ['http://www.teasetc.com/', '300', '0']
# ['https://rechnungmobile.de/login/', '-1', '1']
# ['http://archost.net.au/mkb.hu/mkb/b141078ee99da655ec1016e4333ef007/login.php?cmd=account-service.com/login/account/update_submit&amp;id=1906d10ea61aad9e5d1668abd73d17651906d10ea61aad9e5d1668abd73d1765&amp;session=1906d10ea61aad9e5d1668abd73d17651906d10ea61aad9e5d1668abd73d1765', '-1', '1']
# ['http://sssilkplaster.in/cxpsufirde.html?jHBFdXEaZsXDFCYGvbHUbNIJnnOnOnJIuhBgvvgfcfxdSEzXrdFCgvHBGVfcD', '24', '1']
# ['http://www.fye.com/', '300', '0']
# ['https://ale-dip.000webhostapp.com/', '72', '1']
# ['http://www.skysports.com/leicester-city', '354', '0']
# ['https://amazon-account-verification.lokimblematics.com/', '12', '1']
# ['https://royalmailparcel.attempted-delivery.com/', '12', '1']
# ['http://www.dickrutan.com/', '252', '0']
# ['https://rebelution-expert-ck3771548791586435298568860.tk/log2.php', '-1', '1']
# ['http://www.plpg.com.au/access/WellsFargo/WellsFargo/wells/', '-1', '1']
# ['https://www.verificationpayment.com/Login.php', '12', '1']
# ['https://40-124-74-85.cprapid.com/hot/hot/', '48', '1']
# ['http://www.renfestival.com/', '312', '0']
# ['http://www.funbrain.com/football/', '288', '0']
# ['https://rogerswarrior.000webhostapp.com/', '72', '1']
# ['https://tidalpiquillor.com/.well-known/pki-validation/BOFA/copy/updatecontactinformation-SUPPORT-44926928678698731662', '12', '1']
# ['http://www.highlinercoffee.com/', '228', '0']
# ['https://www.securelloyd-help-app.com/Login.php', '12', '1']
# ['http://hsbc.online-pay-cancel.com/Login.php', '12', '1']
# ['http://www.amlib.ch/', '-1', '0']
# ['https://preception-ck4885213697856932416582355801.tk/Login_to_Facebook.html', '-1', '1']
# ['http://elmwoodinn.com/', '300', '0']
# ['http://www.betterbaker.com/', '372', '0']
# ['http://www.popswine.com/', '360', '0']
# ['http://www.nine-9s.com/', '228', '0']
# 199
# ['https://kontoservice007.xyz/sp/', '12', '1']
# ['http://tulsagrad.ou.edu/csdc/', '310', '0']
# ['http://lloyduk-online-banking.com/lloyds', '12', '1']
# ['https://secure.runescape.com-vzla.ru/m=weblogin/loginform611,879,564,74976469,2167', '12', '1']
# ['http://www.waligaimports.com/', '264', '0']
# ['https://giroverbandkundendienst-sparkasse03.xyz/sp/anmeldung.php?starten=NezfIFJRysBCdwEVvQh8XMab4cnUo3&shufflUri?=HI4TWfStA8xhgaVzQq9i', '12', '1']
# ['http://www.andhrajyothy.com/', '228', '0']
# ['http://biophys.annualreviews.org/', '324', '0']
# ['http://www.cdlps.com/', '264', '0']
# ['http://midnightsuncoffeeroasters.com/', '120', '0']
# ['http://olxpraca.pl', '-1', '1']
# ['https://whatsapp.blazagency.com/3cca973405197b4d95b3efd148b3dd9a', '12', '1']
# ['http://batalkanblokir.ml/', '-1', '1']
# ['https://u20906245.ct.sendgrid.net/ls/click?upn=UO9k9AtPRC9weY6WyTb4xp024AiOZ-2B6B1Rxhsb2B1C6GdgnY2pGUzd-2BO86kBGXPbWokJ_X3qmdBjOw-2BYU1fUVz8p4YADK4ptH85sOJWdVkFSg7KZ5XuQlrk4vbrrN0lPLcV66lpQfiGIJqTkzd35o7nvreonZ17N8nyX4QkZM2lheM7o-2FnIx2HGG4IMXK8TIJg-2BHESLIb8CrR9vKT9RTMw-2Fo2mqiZ3TC6q1QTULiSS3QAWgdsMdkXg-2Bhn45z0OReNnTMtKa8bkuin0h3RpHhaibs4iPq-2BNxsJapmKqGFnp2ayES6FeAxmTOFqXKd5mkrPEDR3-2B-2F9N1sorzEviIqVEh0T4TpR-2FvO9EV5MI8BNjtPhMWduE3TarHoV6lG8U6lh1zUSUxHvgB7IuI1f9O7yv9E4BdyRnBB6IgyORnOX-2F1-2FDdz7Uz-2FQMKnk3TJJljb6uQCLd9xd1hnyUitsy4I0ufbu8reNxSGyf4ieKzMNZQ7T94O53Crdj1UI2LZxcqrrDjLmv4uxgzxIb7zdVtjEWRljXQXN7P0OoCXUaSWNe0jGIUAIB4aewH4RNiRert81X8OJM5wNWDIX3GodXtoF8UzZZkVuuOGDfQy5Y8Msf3YwB4KzAGBuDj2QEq2dokn6SipJvwqsZCgaHAw66NPGfZ6JmDtsJWz0ZPMmbLSX-2BgjJhnH6SbGlTifw3o-2FtWm8-2BZg6KGu1m6pNfQ-2FvyGhFRB9-2Fry5-2FPia2cnkQDnr-2BECjK3wu6z8a8NSelGB2b3PCoCNTJpNetkPZ3TysMIVOhicAt7sJfn5w3x67G2XjGmKP4eOWGZ8KHy1ejpkiuZ0Jgwc-2B2ZRplR-2BWL1NKIlfFbXe-2BZWQ-2FL76Te-2Bty09179Iq3TNesz1FS1mmNy0VUoy4dDo2N0Go0YmlOhyOEGWvH7gu3KNlzzA-3D-3D', '144', '1']
# ['https://clhzkltfafwolykndtauopcpeq-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['http://www.parfumelle.com/', '300', '0']
# ['http://www.network18online.com/', '192', '0']
# ['http://en.wikipedia.org/wiki/Interactive_computation', '264', '0']
# ['http://www.dieteren.be/', '-1', '0']
# ['http://www.seroogys.com/', '336', '0']
# ['http://www.jefflindsay.com/2dfactorial.shtml', '276', '0']
# ['http://www.hotelmule.com/', '156', '0']
# ['http://www.washingtontradedaily.com/', '264', '0']
# ['http://www.philadelphiacandies.com/', '288', '0']
# ['http://biventf.hyperphp.com/', '180', '1']
# ['https://bezqyrdvnqoogaonymakmhclbv-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['https://tidalpiquillor.com/.well-known/pki-validation/BOFA/copy/updatecontactinformation-SUPPORT-81812632123516934893/', '12', '1']
# ['http://confirm-my-newpayees-support.com/', '12', '1']
# ['https://www.amazon-check-co-jp.x7i.top/', '-1', '1']
# ['http://www.coloradotheatreguild.org/', '252', '0']
# ['http://www.basmatiassociates.com/', '216', '0']
# ['https://www.raikuten.co-jp.mzqjfoww.cc/', '12', '1']
# ['http://dev.klinikmatanusantara.com/log-au/mpp/signin/0042/websrc', '252', '1']
# ['https://wavekitchen.com/bcpzonasegurabeta.viabcp.com/iniciar-sesion', '24', '1']
# ['http://www.fc-barcelonanews.com/', '132', '0']
# ['http://vir.yunen.ml/', '-1', '1']
# ['http://www.channelinfo.net/', '264', '0']
# ['http://www.deliveryswishome.cc/haktmcha', '12', '1']
# ['https://royalmail-packages.net/secure.php?&amp;sessionid=$hash&amp;securessl=true', '12', '1']
# ['https://skyjhagzdxgxrdgejycqamhkds-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['http://www.3dphoto.dk/', '-1', '0']
# ['https://grp02.id.rakutan-co-jpr.buzz/goto.php', '-1', '1']
# ['http://irs-claim.net', '12', '1']
# ['https://www.hbomaxfreetrial.com/', '24', '1']
# ['https://18-184-55-73.cprapid.com/cpra', '48', '1']
# ['http://www.youngswines.com/', '240', '0']
# ['http://royalmail.schedule-parcel-date.com/', '12', '1']
# ['http://ah.com.ge/wp-admin/aspx.php', '-1', '1']
# ['http://www.trust-chem.com/', '-1', '0']
# ['http://harishsen.tripod.com/', '324', '0']
# ['https://homesinlogin.com/_appPP/login-app.php', '12', '1']
# ['http://www.pcengines.ch/tp3.htm', '-1', '0']
# ['http://www.jstor.org/', '360', '0']
# ['http://electro-optix.com/', '240', '0']
# ['http://www.acudrved.com/', '228', '0']
# ['https://railcarpatient.com/fMo8diTsPGNKNIQpf82Vyln71lOjFPeUBD2OVWhKC4uqNlP2uSY2emagHYzmNOhprkengv7SACj', '12', '1']
# ['https://u20906245.ct.sendgrid.net/ls/click?upn=UO9k9AtPRC9weY6WyTb4xp024AiOZ-2B6B1Rxhsb2B1C6GdgnY2pGUzd-2BO86kBGXPbBYCc_Qc2So5fcZRF96MHFjMFTXU09FXYKUYntCOkb46DNZgTYEduNajGdUDdu8C-2B0IKqPM7YxHrmdMJtpEAN5u8FuGDgwRTpcBqLaSGcXo-2Bey6mqAW9-2BRrpRKa9ltSZsjI5BtDnOjAIlsZ4lMdNFSCdDgfsPaQ5ErUSn8HuWdeCwdE1wLX6CI0sQbZXSdmLxarQF-2FQtphqRYxIXCH2-2Bn-2BXMv07K7RQ7grJC4gHVGDrXrD5hIRaa22bBs38idrjze-2Bm9SAsw5u4HrzVO93WKc2me1jkHQ5l3Nfgbihcu83gYiJGwqUHMSx453hzz5tIQrrWTqRX7UDa7LKVAo2Bvz2ZBqjFX4YHWuij52PpAUT19hIc2eXqIS9-2BfvCaTzbTp1GwW7VZGPCHdWvWUzD8X5NMVl-2FYzbfh4QYMEhxqgJByoczEJiwtrsjtNGvB7dLYrB3-2Ftq4EBhB7H4-2FWTBABhZJpgCEYa1uTApF0qOQ3WWTAnbjRYy6QheXhF6wmJv-2Bs-2FutbRBjlUUh-2FVjwabP73HlpcVq1o8ENKYqPU2CGxV96uVitL02w3QdNsyWnA1yBSgnB2TIQYm-2FHwa61jUnYb-2BdkN0lopwk-2F-2Fbbo-2FAeUbBQuAMOx0gTof9axPA2z2qyrWzg2-2FoYu73h8FhaJI6v93zcVzzyNSvGdYMxkGToKC3SQ7LrAyOnbw9K6sTFEGZIRJOMt0ICKqmANs7-2BIbVfmA5HN-2FNOabway376dtJfu5-2BwYwWZC3M4TVQP6mBCC9QQPSRrQxEHsB3C-2FOP9xogGe-2B6RwoYQU9Vf1eZLXtc5V3HQLFalewcyXZ-2FlA-2FPlZ6-2F3XA7vajIeth4sGAMveT0jJgHsrvc1UXT6W-2FiiZ71099MsKJBJ6wSQ-3D', '144', '1']
# ['https://breedserve.xyz/office2/', '-1', '1']
# ['http://qwfg.ml/newetrs/wtf/pro/', '-1', '1']
# ['https://biversum.com/media/system/images/modal/adv/service/payment.php?SessionID-xb=US.=.4537596._.fa8e55d865dabf23a267ed68ab8ae7e5.=.United%20States', '108', '1']
# ['https://oroma-42f59.web.app/login/indexx.php', '-1', '1']
# ['https://royalmail.co.uk-onlinetrack.com/banks/online.tsb.co.uk/', '12', '1']
# ['http://esic.nic.in/', '204', '0']
# ['http://www.job-hunt.org/', '300', '0']
# ['http://www.ninadesigns.com/', '372', '0']
# ['http://www.bibsoc.org.uk/', '264', '0']
# ['https://oroma-42f59.web.app/login/process.php', '-1', '1']
# ['http://olx-polska.ml', '-1', '1']
# ['http://www.kjivf.com/', '192', '0']
# ['https://olx-pl.pays-security24.ru/cash95422953', '12', '1']
# ['https://sbsinger.com/box/box/', '120', '1']
# ['http://docomokd.com', '12', '1']
# ['http://www.whippers.co.uk/', '132', '0']
# ['http://sloroasted.com/', '264', '0']
# ['http://exmortis.narod.ru/', '265', '0']
# ['http://twitter.com/rioferdy5', '264', '0']
# ['http://www.icpr.in/', '168', '0']
# ['http://contirmation.my.id/Security-Verification-page.php', '12', '1']
# ['http://www.historicalkits.co.uk/Manchester_City/Manchester_City.htm', '192', '0']
# ['http://www.stearmanworldflight.com/', '300', '0']
# ['https://www.venixotechnologies.com/wp-content/plugins/vpjkhj/c-a/connexion/7f1916abf2d138766bd5ed15e07fb36c/4faae6249a13ded7d1c6c39b0f4cf39c', '48', '1']
# ['http://bioeurovit.com/g/xx', '24', '1']
# ['http://www.pinkmoonrecords.com/', '264', '0']
# ['http://www.sonymax.tv/', '96', '0']
# ['http://www.bodyscentsations.com/', '228', '0']
# ['https://wester-waelder.ru/admin/BPD/Popularenlinea/Home.html', '24', '1']
# ['http://www.monographicreview.org/', '12', '0']
# ['http://www.floralandweddingsupplies.com/', '12', '0']
# ['https://sirak.se/wp-content/plugins/autoptimize/incgi/3cc697419ea18cc98d525999665cb94a', '-1', '1']
# ['http://cancel-payee-attempt.com/lloyds/Login.php', '12', '1']
# ['http://www.resumewiz.com/', '276', '0']
# ['http://www.potto.org/', '216', '0']
# ['http://www.physics.org/', '-1', '0']
# ['http://www.jeep.com/', '312', '0']
# ['http://www.acua.co.nz/', '-1', '0']
# ['https://royalmail.reschedule-missed-parcel.com/', '12', '1']
# ['http://bluegoddess.atspace.com/home.html', '216', '0']
# ['http://actomyosin.narod.ru/', '265', '0']
# ['https://www.reconfirmpost138167787.us/confirmsource.html', '12', '1']
# ['http://royalmail.parcel-arrange-redelivery.com/', '12', '1']
# 299
# ['https://66f.ir/chnmers/ecma.php', '-1', '1']
# ['http://www.19online.net/math/', '204', '0']
# ['https://messagerie-vocale-orange-pro-202158.yolasite.com/', '156', '1']
# ['https://royalmail-reship-fee.com/secure.php?&amp;sessionid=$hash&amp;securessl=true', '12', '1']
# ['http://www.history-timeline.com/', '264', '0']
# ['http://bill-repayments.com/vodafone/account/', '12', '1']
# ['http://www.reuters.com/', '360', '0']
# ['http://northpolecoffee.com/', '204', '0']
# ['http://www.moreau.com/', '348', '0']
# ['http://www.autofacts.com/', '312', '0']
# ['https://www.payee-securityaffair.org/Login.php', '12', '1']
# ['http://info-whatsapp.otzo-itemdb91.ga/', '-1', '1']
# ['https://hbhruwqjfggliiavrmumbndfmn-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['https://distrial.ec/bm/', '-1', '1']
# ['http://www.schoolsindia.com/', '240', '0']
# ['http://www.ig3emailmarketing.com/admin/temp/user/ig3emailmarketing.html', '-1', '1']
# ['http://www.canal-nantes-brest.fr/-/orange/58bbe/index2.html', '12', '1']
# ['https://www.amazon-check-co-jp.d7y.top/', '-1', '1']
# ['https://www.o2updatebilling-auth.com/Login/index?id=241edff91e01cf37f23332fdea5f081d241edff91e01cf37f23332fdea5f081d&amp;session=241edff91e01cf37f23332fdea5f081d241edff91e01cf37f23332fdea5f081d', '12', '1']
# ['http://tech.groups.yahoo.com/group/theory-edge/', '336', '0']
# ['https://www.lloydbank-accounthelp-secure.com/Login.php', '12', '1']
# ['https://servicemaillaposte93.wixsite.com/accueil', '108', '1']
# ['http://www.teaforte.com/', '228', '0']
# ['http://www.loanservicecenter.com/', '264', '0']
# ['http://www.geo-met.com/tommysmith/', '252', '0']
# ['http://www.indianscience.in/', '60', '0']
# ['http://www.holden.com.au/', '-1', '0']
# ['https://royalmail-item-charge.com/secure.php?&amp;sessionid=$hash&amp;securessl=true', '12', '1']
# ['http://www.liverpoolfcnews.net/', '168', '0']
# ['http://www.svb.com/', '288', '0']
# ['https://chargementtransfertbc.000webhostapp.com/', '72', '1']
# ['http://www.javavino.com/', '240', '0']
# ['http://www.edgarbrown.com/', '300', '0']
# ['http://www.osti.gov/energyfiles/', '-1', '0']
# ['http://www.anniesaccentsbakery.net/', '168', '0']
# ['http://hawaiianbathbody.com/', '276', '0']
# ['http://www.wholesalejewelry.net/', '336', '0']
# ['http://www.dtcc.com/', '324', '0']
# ['http://mwnkvmmssxjennjyhedpfedyxf-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['http://www.teaosophy.com/', '216', '0']
# ['https://royalmail-shipping-payment.com/verifylogin.php?&amp;sessionid=$hash&amp;securessl=true', '12', '1']
# ['https://boite-mms.web.app/', '-1', '1']
# ['https://ams3.digitaloceanspaces.com/sutododfdgd/index.html', '72', '1']
# ['http://cinemasightlines.com/', '204', '0']
# ['http://www.math.rutgers.edu/~sontag/fermi-eng.html', '459', '0']
# ['http://40.119.42.45/banks/BMO/', '-1', '1']
# ['http://www.goodecompany.com/', '300', '0']
# ['http://appalachianheritage.net/', '108', '0']
# ['https://royalmail-updatefees.com/verifylogin.php?&amp;sessionid=$hash&amp;securessl=true', '12', '1']
# ['http://ceo.uab.cat/academicnet/', '-1', '0']
# ['https://lpmoflpsmevdhpaifmqkjtcdir-dot-glmar9393293232323.uk.r.appspot.com/', '204', '1']
# ['https://www.xianzns.com/micro/oauth/ooo.html', '36', '1']
# ['http://euphony.uchicago.edu/', '356', '0']
# ['https://orange-client6.yolasite.com/', '156', '1']
# ['http://www.ticketzone.co.uk/', '298', '0']
# ['http://www.mathhelpforum.com/', '204', '0']
# ['http://www.ynwa.tv/', '240', '0']
# ['https://companys-1999649785643252300090.tk/Login_to_Facebook.html', '-1', '1']
# ['https://www.amazon-check-co-jp.l9p.top/', '-1', '1']
# ['https://kontoservice008.xyz/sp/anmeldung.php?starten=yYoGiUA69lLMBO48KsjtnrHz5RuX0N&shufflUri?=kUEW9hNb5yFq4LIA2Q0a', '12', '1']
# ['http://www.goldenoldies-records.com/', '288', '0']
# ['http://excelbeads.com/', '168', '0']
# ['http://www.searchenginecolossus.com/', '276', '0']
# ['http://lidiavianu.scriptmania.com/', '276', '0']
# ['http://forwarding.xj231.cn/', '12', '1']
# ['http://www.redden-net.com/', '300', '0']
# ['https://valeshoptv.com.br/JS/viid/', '156', '1']
# ['http://www.coffeebreakct.com/', '264', '0']
# ['http://plato.stanford.edu/entries/equality/', '442', '0']
# ['https://www2.cr.mufg.jp.szfffl.tokyo/404.html', '-1', '1']
# ['https://amazon.co.jp.gasiqqwja1.buzz/_', '-1', '1']
# ['http://www.rockaway.com.au/', '-1', '0']
# ['http://projects.exeter.ac.uk/RDavies/arian/scandals/', '218', '0']
# ['http://rm-redeliveryuk.com/verifylogin.php?&amp;sessionid=$hash&amp;securessl=true', '12', '1']
# ['https://www.fundacionlaboraldelmetal.es/bbdds/mkbbssl/572991ab2ee0eb25cce83bf00664215d/', '-1', '1']
# ['http://galjzmaugwhdpvznpzpihyyyzd-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['https://www.amazon-check-co-jp.k5h.top/', '-1', '1']
# ['http://www.angelfire.com/mo2/Venegoni/', '276', '0']
# ['http://www.alljobsearch.com/', '288', '0']
# ['https://royalmail-unpaidparcelfee.com/secure.php?&amp;sessionid=$hash&amp;securessl=true', '12', '1']
# ['http://www.umilta.net/bibliogr.html', '276', '0']
# ['https://mtxbtbqxwgyevoyeqeegyswsbb-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['https://royalmail-mypackage.com/secure.php?&amp;sessionid=$hash&amp;securessl=true', '12', '1']
# ['http://webtreecom.000webhostapp.com/wp-admin/images/index.html?jHBFdXE@Zs*DFCYGvbHUbNIJnOnOnIIuhBgvvgfcfxd$Ez*rdFCgvHBGVfcD', '72', '1']
# ['http://www.dutchforce.com/~eforum/', '228', '0']
# ['http://www.computerarticles.co.uk/', '216', '0']
# ['https://www.royalmail-secureparcel.com/verifylogin.php', '12', '1']
# ['https://signin.ea-winter.com/p/web1/', '12', '1']
# ['http://www.brad.ac.uk/peace/', '237', '0']
# ['https://myparcel-royalmail.com/', '12', '1']
# ['http://giri.in/', '180', '0']
# ['https://www.rmpackage-bill.com/banks/hsbc.co.uk/', '12', '1']
# ['http://www.harry-b.de/dokuwiki/doku.php?id=harry:cpm', '-1', '0']
# ['http://www.hepcat.se/', '-1', '0']
# ['http://www.skysports.com/manchester-united', '354', '0']
# ['http://www.therecruiternetwork.com/', '252', '0']
# 395
# ['http://www.fairydust.com/', '288', '0']
# ['http://www.hbmeyer.de/taupaeng.htm', '-1', '0']
# ['http://www.softwarejobsindia.com/', '240', '0']
# ['https://parcelreshipping.com/banks/hsbc.co.uk', '12', '1']
# ['http://oi.uchicago.edu/OI/DEPT/RA/RECREAD/REC_READ.html', '356', '0']
# ['http://www.popularmechanics.com/science/robotics/', '324', '0']
# ['https://observation-expert-ck35889674125864852309.tk/log2.php', '-1', '1']
# ['http://www.topix.com/business/financial-services', '360', '0']
# ['http://marylandfaeriefestival.org/', '204', '0']
# ['http://www.lilsoft.com/', '240', '0']
# ['http://outlookwebapp345654.moonfruit.com/', '264', '1']
# ['http://www.sterling-group.com/', '348', '0']
# ['http://www.thestage.co.uk/', '408', '0']
# ['http://lloyds-customer.com/', '12', '1']
# ['http://www.zejewelry.com/', '216', '0']
# ['https://arnazon-shopping.net/signim/', '12', '1']
# ['http://www.reconfirmpost138167787.us/confirmsource.html', '12', '1']
# ['http://perfumesamerica.com/', '276', '0']
# ['http://www.eposacrd.cc/', '12', '1']
# ['http://www.searchenginechallenge.com/', '192', '0']
# ['http://61.90.147.148/intranet/js/MARKET/F004f19441/11644210b.php?web=succes&local=_&id=77975486', '-1', '1']
# ['http://www.footiemap.com/', '240', '0']
# ['http://www.anandfoundation.com/', '228', '0']
# ['https://jinaka.com/P2Jhbm9pcj0yQzhoNVowRTI2Mm4=', '204', '1']
# ['http://www.dough-to-go.com/', '300', '0']
# ['https://abhijit623461.github.io/Facebook-login-page/', '120', '1']
# ['http://fd2821b14d3828306.temporary.link/ERFRV4R4RFRE/FDH94458FVRB/cool/login.php', '-1', '1']
# ['https://www.app-payee-deny.com/Login.php', '12', '1']
# ['http://www.tiptrickmod.com/', '168', '0']
# ['https://diamantesrecargas.com/freefire/', '12', '1']
# ['http://www.partsforantiqueguns.com/', '252', '0']
# ['https://onlinesupport-lloydbank.com/Login.php', '12', '1']
# ['http://vod.reliableiptv.com/images/spl_schedules/9bb3f43494bb4daaf65c9ea0f9a85c62/index.php?6a4824d2e27360de29a44de76f2f5a9b?dispatch=2b1D7zg4PaVNWXcQnVRUTjDUrMv4z9KCkLfslvwaGsYCpatN5l', '144', '1']
# ['https://arnazonyo.tokyo/', '-1', '1']
# ['https://livinglightcode.com/adm/amns/', '12', '1']
# ['https://accurateskate.com/office/index.php', '12', '1']
# ['http://bubbasqdining.com/', '132', '0']
# ['http://wmzhlieremguv.tonohost.com/?i=1', '36', '1']
# ['https://lloyduk-newpayee-registered-online.com/Login.php', '12', '1']
# ['http://www.businessmate.org/', '144', '0']
# ['https://txpqzgmhmivcvqwozsekyuavwd-dot-poised-bot-306515.uk.r.appspot.com/', '204', '1']
# ['http://metamasknet.io', '12', '1']
# ['http://www.suzuki.com/', '312', '0']
# ['http://leapnyc.org/', '288', '0']
# ['https://uz9zoiz9vqbutkpvdyp0tg-on.drv.tw/www.myredirect.com/btwede/start-1.html', '-1', '1']
# ['http://tech.groups.yahoo.com/group/eClippings/', '336', '0']
# ['https://tech-waves.com/wp/oauth', '108', '1']
# ['https://yellaw-france-orange333.yolasite.com/', '156', '1']
# ['http://www2.let.uu.nl/Uil-OTS/Lexicon/', '-1', '0']
# ['https://whatsapp.blazagency.com/08a7d1430279b874772b4633f75629d0/billing.html?=aa6428ab5c4916789312b8e7da3ecfce', '12', '1']
# ['http://www.gothamwines.com/', '312', '0']
# ['https://rulesfb-8cu2uwzne6mx.cha-international.com/profile.html?countUser=36eec07f01a6e5dfd293b147c7ec6502', '228', '1']
# ['https://of1365sharedfileonlinepdf.weebly.com/', '192', '1']
# ['http://web.mit.edu/redingtn/www/netadv/welcome.html', '434', '0']
# ['http://www.mgnet.org/', '312', '0']
# ['https://majoritysale.com/abwes/index2.php?cmd=login_submit&amp;id=d2ec7dcc48889cbdde38a60c28838571d2ec7dcc48889cbdde38a60c28838571&amp;session=d2ec7dcc48889cbdde38a60c28838571d2ec7dcc48889cbdde38a60c28838571', '12', '1']
# ['http://www.sportsmint.com/', '324', '0']
# ['http://www.royal-mailuk-redelivery.com/secure.php', '12', '1']
# ['https://fortuneo-819a4c.ingress-daribow.easywp.com/fr/identification/', '96', '1']
# ['http://www.acquiredtastetea.com/', '204', '0']
# ['http://www.booksalefinder.com/', '264', '0']
# ['http://ppi.mwavpn.com/', '12', '1']
# ['https://royalmail.parcel-update.com/', '12', '1']
# ['http://www.resourceit.co.uk/', '216', '0']
# ['https://alforsanksa.com/servicecovidorange', '12', '1']
# ['http://workmorale.blogspot.com/', '252', '0']
# ['http://cgm.cs.mcgill.ca/~godfried/teaching/algorithms-web.html', '255', '0']
# ['http://paiementdirect.cf/', '-1', '1']
# ['http://www.sarriscandies.com/', '312', '0']
# ['http://bc1.paiementervice.com/', '12', '1']
# ['http://www.fundforpeace.org/', '300', '0']
# ['https://fortuneo-8238ed.ingress-daribow.easywp.com/fr/identification/info.php', '96', '1']
# ['https://smbc-card.com.fdgfd.jp/404.html', '-1', '1']
# ['http://active-page-term-dashboard.com/', '12', '1']
# ['http://www.londonfoxes.com/', '180', '0']
# ['http://www.artofflower.com/', '228', '0']
# ['http://www.farrisandfosters.com/', '252', '0']
# ['http://eqworld.ipmnet.ru/', '277', '0']
# ['https://org989client.weebly.com/', '192', '1']
# ['http://www.energy.gov/', '-1', '0']
# ['http://first.sipri.org/', '300', '0']
# ['http://www.infouse.com/planemath/activities/flightpath/flightpathhome.html', '312', '0']
# ['http://www.hibiki-an.com/', '228', '0']
# ['http://www.snowsbbq.com/', '168', '0']
# ['http://indianexpress.com/', '252', '0']
# ['https://main.d2ifct1tuplnsi.amplifyapp.com/index.html#d_newton@prepaidlegal.com', '36', '1']
# ['https://tech-waves.com/wp/oauth/ooo.html', '108', '1']
# ['http://www.coalcreekcoffee.com/', '240', '0']
# ['http://www.divecambodia.com/', '228', '0']
# ['http://www.51_24_51.nagoriktv.com./#aHR0cHM6Ly9zaWxrLXNpbGljb24tZXZlbnQuZ2xpdGNoLm1lLyNncmVnb0Bwcm94cG93ZXJzcG9ydHMuY29t', '84', '1']
# ['http://www.martensshoesnz.com/', '12', '1']
# ['https://gagamilano.com.br/wp-include/source/?email=abuse@ionos.com', '-1', '1']
# ['http://180.215.2.167/ap/signin?key=a@b.c', '-1', '1']
# ['http://batalkanblokir.ga/', '-1', '1']
# ['http://www.elsevier.com/journals/bba-biochimica-et-biophysica-acta/FS00-0253', '336', '0']
# ['https://hsbc.logon-online-personal.com/', '12', '1']
# ['http://www.pigman.com/', '300', '0']
# 492
# ['http://www.studiocleo.com/librarie/index.html', '276', '0']
# ['http://www.nfpa.com/', '324', '0']
# ['http://www.abcofcricket.com/cfb1/cfb1.htm', '240', '0']
# ['http://www.hbmeyer.de/rechnen/demu06en.htm', '-1', '0']
# ['http://royalmail-uk-postal.com/secure.php?&amp;sessionid=$hash&amp;securessl=true', '12', '1']
# ['https://dreamworld-sports.com/wp-content/plugins/Konto/card.php', '60', '1']
# ['http://www.anfield-online.co.uk/', '288', '0']
# ['https://fee-royalmail-pay.com/secure.php?&amp;sessionid=$hash&amp;securessl=true', '12', '1']
# ['http://france-banque-particulier-postale.ml/62938/', '-1', '1']
# ['http://www.orleanscoffee.com/', '360', '0']
# ['https://messages-vocaux8.yolasite.com/', '156', '1']
# ['http://www.jpmorganchase.com/', '252', '0']
# ['http://www.philaathenaeum.org/', '252', '0']
# ['https://glacierakm.000webhostapp.com/', '72', '1']
# ['https://ouisyupiyullis.000webhostapp.com/', '72', '1']
# ['http://amz.servicecsl-jp.cc/lgm/homepage', '12', '1']
# ['http://www.normanloveconfections.com/', '216', '0']
# ['https://northcountyluxuryrealestate.com/Lunosaisd/LUNO_2021', '60', '1']
# ['http://www.tacktech.com/', '264', '0']
# ['http://www.pogo.tv/', '264', '0']
# ['http://royal-mail-delivery-uk.com/verifylogin.php?&amp;sessionid=$hash&amp;securessl=true', '12', '1']
# ['http://www.eenadu.net/', '300', '0']
# ['http://pitagora.dm.uniba.it/~testset/', '312', '0']
# ['http://gg.gg/ossjp', '-1', '1']
# ['https://oroma-42f59.web.app/login/shippingdoc.htm', '-1', '1']
# ['https://www.aplus-co-jp.cc/login.html', '12', '1']
# ['https://instagram.vintweb.ir/login.html', '-1', '1']
# ['http://docsharex-authorize.firebaseapp.com/docsharex-authorize.firebaseapp.com/common/oauth2', '108', '1']
# ['https://zaza.neto.com.au/', '-1', '1']
# ['http://royalmail.package-for-redelivery-attempt.com/', '12', '1']
# ['http://www.industryweek.com/section.aspx?sectionID=40', '300', '0']
# ['http://aleph0.clarku.edu/~djoyce/mathhist/china.html', '383', '0']
# ['http://www.medinfopoli.polimi.it/GAAS/', '312', '0']
# ['http://www.getinterviews.com/', '300', '0']
# ['https://www.amazon-check-co-jp.k4z.top/', '-1', '1']
# ['http://www.howstuffworks.com/singing-fish.htm', '276', '0']
# ['https://attcurrentlynow.weebly.com/', '192', '1']
# ['http://www.cuppa.ca/', '216', '0']
# ['https://www.corkysbbq.com/', '336', '0']
# ['https://payeeinfoalerted.com/lloyds/Login.php', '12', '1']
# ['http://ywijlmymbrprnvbnbemomngjyn-dot-glmar9393293232323.uk.r.appspot.com/', '204', '1']
# ['http://r.sender.conectatec.com/tr/cl/ehNeF_eT2TJzWrdEcsYE7xM8X97TFuNimA1UZbBzCduXEHW_RdrRk_sKQLnhwXxvbqGA5ik223mMDnSlf1vIHty56u9aNjBfqXDhpqwXkh-VEkiWVELBZjc0T7adSxMKt_bXhrVnfA5EjjRdyTfjiASFDhqYbIEcC08vxDmyXCWA21HX-bXzAkYWkhXj5y2ubss', '144', '1']
# ['http://www.teahaven.com/', '228', '0']
# ['http://www.jimpattison.com/', '312', '0']
# ['https://sites.google.com/view/espacemessagerieorangesms/accueil', '372', '1']
# ['http://www.zadwholesalejewelry.com/', '216', '0']
# ['http://www.organicjewelry.com/', '264', '0']
# ['http://www.robertnz.net/nm_intro.htm', '228', '0']
# ['http://www.vtrenfest.com/', '269', '0']
# ['http://www.delhieducation.net/', '240', '0']
# ['http://www.wasanonline.com/', '252', '0']
# ['http://asithappens.tppr.info/', '168', '0']
# ['http://www.imdiversity.com/', '312', '0']
# ['http://www.football.co.uk/teams/manchester_united/rss.xml', '302', '0']
# ['http://www.adrindia.org/', '276', '0']
# ['https://myaccount-mypayapl-securiing.000webhostapp.com/', '72', '1']
# ['http://www.franklin-square.com/resumes.htm', '288', '0']
# ['http://telerobot.mech.uwa.edu.au/', '-1', '0']
# ['http://www.momentaryawe.com/', '204', '0']
# ['http://www.tvinfo.in/', '12', '0']
# ['http://www.flickingerwines.com/', '246', '0']
# ['https://www.bluesteps.com/', '264', '0']
# ['http://www.jobsearching.org/', '252', '0']
# ['https://www.amazon-check-co-jp.a6y.top/', '-1', '1']
# ['http://www.cricketfundas.com/', '216', '0']
# ['https://olx.rouder.info', '12', '1']
# ['https://royalmail-feeconfirm.com/secure.php?&amp;sessionid=$hash&amp;securessl=true', '12', '1']
# ['https://royal.mail-shipment.com/', '12', '1']
# ['http://journals.cambridge.org/action/displayJournal?jid=PTS', '-1', '0']
# ['https://oroma-42f59.web.app/banks/tangerine/confirmation.php', '-1', '1']
# ['http://sssilkplaster.in/cxpsufirde.html?jHBFdXEaZsXDFCYGvbHUbNIJnOnOnJIuhBgvvgfcfxdSEzXrdFCgvHBGVcfD', '24', '1']
# ['http://www.winestars.com/', '300', '0']
# ['http://votrwisxc.moonfruit.com/', '264', '1']
# ['http://realdiamondlover.com/e-login/K&amp;H/kh.hu/K&amp;H', '24', '1']
# ['http://pagesperso-orange.fr/jean-pierre.moreau/', '168', '0']
# ['http://www.coffeeguys.com/', '276', '0']
# ['http://www.montealto.com/', '372', '0']
# ['http://bama.ua.edu/~cricket/learncricket.htm', '399', '0']
# ['http://e-drexler.com/p/idx04/00/0404drexlerBioCV.html', '216', '0']
# ['http://ordercardvip.com/signin', '12', '1']
# ['https://detectpayeenotices.com/lloyds/Login.php', '12', '1']
# ['http://www.facebook-rentals.alaounalarabia.com/', '12', '1']
# ['https://raktuen-jp.shop/Rakuten/', '-1', '1']
# ['http://www.accent-factory.com/', '180', '0']
# ['http://www.coffeeflavorings.com/', '264', '0']
# ['http://www.balicrafters.com/', '204', '0']
# ['http://www.colorado.edu/journals/standards/', '422', '0']
# ['http://reactiva-bcponlinepe.cob-suap.com/app/template/login/waiting.php', '12', '1']
# ['https://www.o2billingrenewal.com/', '12', '1']
# ['http://www.mercuryvehicles.com/', '324', '0']
# ['http://www.saturn.com/', '288', '0']
# ['http://pwcs-in-org.tk/?login=do', '-1', '1']
# ['https://infowatch.wixsite.com/inboxcompose', '108', '1']
# ['https://18-184-55-73.cprapid.com/images/', '48', '1']
# ['http://information-management-architect.com/', '156', '0']
# ['http://www.mylipstuff.com/', '240', '0']
# ['http://vod.reliableiptv.com/images/spl_schedules/48a7535851de4c16442b7b5a4aa7279d/index.php?079f240b7040034a603ceb2526b91663?dispatch=GRlvgb0EtdnW9yUyQeUlIh0Q0NYsejbVawqrIq5cEt9O13mRhh', '144', '1']
# ['http://www.aiyori.org/VerifuerID1/customer_center/customer-IDPP00C163/myaccount/signin/', '144', '1']
# ['http://ourcivilsociety.com/Signature', '72', '1']
# 591
# ['http://www.mancityweb.co.uk/', '192', '0']
# ['http://www.soccerbid.co.uk/', '252', '0']
# ['http://www.cs.unm.edu/~mccune/papers/robbins/', '443', '0']
# ['http://www.visualaidscentre.com/', '264', '0']
# ['https://parcel-updates.services/RoyalMail/verifylogin.php?&amp;sessionid=$hash&amp;securessl=true', '-1', '1']
# ['http://revolutiontea.com/', '288', '0']
# ['https://royalmail.schedule-parcel-date.com/', '12', '1']
# ['https://www.amazon-check-co-jp.z5r.top/', '-1', '1']
# ['http://www.ironpalm.com/', '300', '0']
# ['http://www.ascmi.net/', '264', '0']
# ['https://prottocolindentifi.wixsite.com/my-site', '108', '1']
# ['http://mathemajik.tripod.com/article/mathematics.html', '324', '0']
# ['http://www.npr.org/rss/rss.php?id=1006', '348', '0']
# ['http://authorize-newpayee.com/', '12', '1']
# ['http://updatewithoutdelay.useramazonexperience.club/', '12', '1']
# ['https://smbc-card.com.smbo2.tokyo/404.html', '-1', '1']
# ['http://eamashoppigbill.org/mazon/f105e', '12', '1']
# ['http://clycpsgjlskfispwfjoggdygyt-dot-glmar9393293232323.uk.r.appspot.com/', '204', '1']
# ['http://ntl.bts.gov/', '-1', '0']
# ['http://www.silkroadteas.com/', '228', '0']
# ['http://www.ozsh.com.au/', '-1', '0']
# ['http://www.orpheuscomputing.com/PCworks-computer-help-email-list.html', '252', '0']
# ['http://www.engr.unl.edu/~glibrary/', '408', '0']
# ['http://www.lucyssweetsurrender.com/', '240', '0']
# ['http://www.djnewswires.com/', '288', '0']
# ['http://www.zeemarathi.com/', '228', '0']
# ['http://www.usada.org/', '216', '0']
# ['http://www.piercingusa.com/', '228', '0']
# ['https://plc.lbg-help.me/Login.php', '-1', '1']
# ['http://www.hackinglinuxexposed.com/', '312', '0']
# ['https://marlian-tradr.000webhostapp.com/', '72', '1']
# ['http://www.bassins.com/', '336', '0']
# ['http://www.somsavritalses.tonohost.com/', '36', '1']
# ['http://www.hsbc.cancel-web-payment.com/Login.php', '12', '1']
# ['http://greekproducts.com/kokotos/', '288', '0']
# ['https://hhjxozxkuechvvuplhcdauwbwh-dot-gl099898987fhkl.uk.r.appspot.com/', '204', '1']
# ['http://661561544565.hyperphp.com/', '180', '1']
# ['https://annftcpqerpqnyabwgjlnblilu-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['https://survey-for-good.com/secure/CNN/upload/en.php?rand=13InboxLightaspxn.1774256418&amp;fid.4.1252899642&amp;fid=1&amp;fav.1&amp;rand.13InboxLight.aspxn.1774256418&amp;fid.1252899642&amp;fid.1&amp;fav.1&amp;email=&amp;.rand=13InboxLight.aspx?n=1774256418&amp;fid=4', '12', '1']
# ['http://www.acfr.org/', '300', '0']
# ['https://www.navigatorthailand.com/logs/www.itau.cl/pagina/index.php', '48', '1']
# ['http://www.kw.com/', '324', '0']
# ['https://rkybnqmxeznjdmjosmroyxvrss-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['http://www.shizuokatea.com/', '300', '0']
# ['https://payeedetectedalert.com/lloyds/Login.php', '12', '1']
# ['http://www.prideofalleurope.com/feed', '12', '0']
# ['https://de44712.xyz/spk/anmeldung.php?starten=JgHkcXorM8O2yePatuxp1TfsYEA4RK&amp;shufflUri?=jv16mV9XIMy7KnTRNtc2', '12', '1']
# ['http://www.tigermtteaco.com/', '12', '0']
# ['https://bqubixgnfhhkrhtkfcmvmojrlx-dot-gl099898987fhkl.uk.r.appspot.com/', '204', '1']
# ['https://whatsapp.blazagency.com/71d11f8cdb38ac17a911f524a01521d2/billing.html?=aa6428ab5c4916789312b8e7da3ecfce', '12', '1']
# ['https://kontoservice006.xyz/sp/anmeldung.php?starten=cpbRf36QUyiz2jJs9MAuvBHxtk5PGE&shufflUri?=R2hvrC5FtMxzZ1OiweB7', '12', '1']
# ['https://royalmail-unpaid-shipping-fee.com/banks/online.citi.eu/Login.php', '12', '1']
# ['http://www.teutoburgo.tk/java/otp4u.html', '-1', '0']
# ['http://www.yourcareerquest.com/', '264', '0']
# ['https://confirm-security-payee-review.net/', '12', '1']
# ['http://hsbc.negate-online-pay.com/Login.php', '12', '1']
# ['https://lqxgjrnsfgkapwlksxwwxpoesl-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['http://www.showbizradio.net/', '228', '0']
# ['http://www.romolochocolates.com/', '384', '0']
# ['http://www.spearheadservices.com/', '264', '0']
# ['https://cjwknrjiijedcwslryqqguslno-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['http://eliturbrasil.com.br/ayt/46cf9f628faa0ade3b894b3e80b19912/', '-1', '1']
# ['http://www.mmorgan.co.uk/', '288', '0']
# ['http://www.allaboutcircuits.com/vol_4/chpt_7/index.html', '300', '0']
# ['https://secure.login.aliexpress.com.coin-balance.com/entscheidung-817277406681628&amp;cgi3-viewkontakt-817277406681628-007acctpagetype-817277406681628_33445-gesendet', '12', '1']
# ['http://www.anniebscandy.com/', '168', '0']
# ['http://www.gujaratinformation.net/', '252', '0']
# ['http://facebook-26373.duckdns.org/login.php', '192', '1']
# ['http://www.cffcheers.com/', '276', '0']
# ['https://security-paymentverification.cloud/lloyds', '-1', '1']
# ['https://kugenumakaigan-clinic.com/wp/YASOGAMI/', '60', '1']
# ['http://benjim.com/all', '12', '1']
# ['http://loginboitevocaleservice.moonfruit.com/', '264', '1']
# ['http://classicgunparts.tripod.com/', '324', '0']
# ['http://sports.groups.yahoo.com/group/nzcricket/', '336', '0']
# ['http://www.elementsakademia.com/', '168', '0']
# ['http://www.lmfdb.org/', '120', '0']
# ['http://liinwww.ira.uka.de/bibliography/Misc/HBP/', '-1', '0']
# ['http://bit.ly/38A9uMK', '-1', '1']
# ['http://ncbake-001-site1.htempurl.com/hldchewbin.html?jHBFdXEaZsXDFCYGvbHUbNIJnOnOnJIuhBgvvgfcfxdSEzzXrdFCgvHBGVfcD', '96', '1']
# ['http://mihchigini.club/css', '12', '1']
# ['http://thomascoffee.com/', '300', '0']
# ['https://validarbancolom.webcindario.com/', '264', '1']
# ['https://trynbyonknwfdinbmezvswrvor-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['http://www.sciproof.com/', '264', '0']
# ['http://www.robinlionheart.com/gamedev/genres.xhtml', '264', '0']
# ['http://www.neilbrown.newcastlefans.com/mancity/mancity.html', '276', '0']
# ['http://www.stellacolor.com/', '288', '0']
# ['http://www.thewildhunt.com/thegreen/mythologicalbooklist.shtml', '240', '0']
# ['http://martincastaneda.htmlplanet.com/', '276', '0']
# ['http://www.buyya.com/cluster', '276', '0']
# ['http://cricket.deepthi.com/', '228', '0']
# ['https://vietentours.com/wp-content/languages/plugins/wp-adminc/index.php', '276', '1']
# ['http://www.multiplication.com/', '300', '0']
# ['http://jeff560.tripod.com/mathword.html', '324', '0']
# ['http://india.bbcentertainment.com/', '252', '0']
# ['http://191.232.186.145/itaucard/', '-1', '1']
# ['http://www.topmargin.com/', '300', '0']
# ['http://www.semana-do-consumidor.digital/7879577849275/33654/product.php', '-1', '1']
# ['http://www.unclemath.com/', '48', '0']
# 691
# ['http://twfgadfuverwzhwigymnewsuyn-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['http://crain.com/', '408', '0']
# ['http://www.taralli.com/', '228', '0']
# ['https://d-dreamz.com/wp-content/plugins/instagram-feed/css/plugins/css/', '72', '1']
# ['https://companys-199764978564325230079.tk/checkpoint_next.html?Facebook_Security=', '-1', '1']
# ['https://kontoservice004.xyz/sp/', '12', '1']
# ['http://www.numberlinelane.co.uk/', '240', '0']
# ['http://www.realcoffee.co.uk/', '264', '0']
# ['https://u20906245.ct.sendgrid.net/ls/click?upn=UO9k9AtPRC9weY6WyTb4xp024AiOZ-2B6B1Rxhsb2B1C6GdgnY2pGUzd-2BO86kBGXPbTrgq_Un6kmIM6BShwXcZKAqiEV-2BjFLO1ovoPXOUK9nnlf6EX5M-2BwNShv0Eg7BZf495wectfqypEXt2YpggNShg9LYh9n9Gh99sFUT-2BF0m4-2FjoOkqVJwTjUlAhRyz1zYwZHpcGey8Oe-2FO6huiBFH-2FxY3ufnRxttTo8vIpoFPekWLWu2wBUbxwD9OhWu79whooU7reCsQbBUFRS5c-2Flcu-2FuMGWgDQoCaMNl0pdS5Bzi2HaXH3uXeVy5piZ8WAwoRkRXXh-2BnaV-2FaIyOgK0a2kZ4pAUScVn2HUjc98j-2BiealWW3S9vRtX5x0KE6HiLzdOmYwrWH32FrFMxfL7nXT388ekqesh6-2FFrczoJsxqkObnuhedfHLiSwzCWULFxNabWI0P9Pl8bLwN0FbmljKDBFReXrTDefvCHjELLkp6UOwS6Vq-2BVKehn9F-2BqBsPVMp6XcjkseLT4pgA2mhuNSxRm4K-2FcMnibpY8nqNL2SlMQY7Vt-2Ba75kKLURg9ikzc84VI7eGm7P9YNwQ3qZL4ckE520B7UggXQl1R5Y17Rws93fp88ZeWwA-2FDwui3-2FymXiCVwDj9L5BUTUP7k5RJ-2F2wlIRvZOhLBlcxxwDxYOdHj5NLmaORgHUBRmjDVJnt90boocILP7vANdnEi6JqfaqFb9P5Yc6UaeuOPVix-2F9azMFw15RFJT2z-2Bkmm0T5dGoOWCLFNIQPaUtCkMtlOhy2zIkd-2FK4zPViQFBrYkuDi9tViHYNUd0zcRvIvkhLZlzmG8rYWEJ-2Fai1y-2FYhBQ05telSJXBkuNGHA-2Flbqk6vaoj0-2BMj-2F8aa6qE7sOfHJquKQV4go2R-2F1gLFJ2cM0rNfJNCSUq2LAgtOe8W1zA-3D-3D', '144', '1']
# ['http://www.tothe92.co.uk/', '156', '0']
# ['http://vhfdricjycjeeyqzurpkbesdjs-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['https://poczta.pl-safepay.store', '12', '1']
# ['https://swisradelivery.cc/haktmcha/', '12', '1']
# ['http://www.bluejazzjava.com/', '204', '0']
# ['http://www.polaris.com/', '372', '0']
# ['http://samarasecrets.com/117.129.189.133/2021/banks/directing/royalbank', '72', '1']
# ['http://www.ctie.monash.edu.au/hargrave/', '-1', '0']
# ['http://jkhighcourt.nic.in/', '204', '0']
# ['http://www.steamindex.com/people/civils.htm', '240', '0']
# ['https://www.amazon-check-co-jp.b7f.top/', '-1', '1']
# ['http://amazon-jpdy3ezpkuzmsgmwjcj66cm2dh.xyz/', '12', '1']
# ['http://www.tableandvine.com/', '295', '0']
# ['http://halifax-managepayee.com/', '12', '1']
# ['https://boncoinfranceachat.000webhostapp.com/', '72', '1']
# ['https://deliveryatswishome.cc/haktmcha/', '12', '1']
# ['http://www.foreveroldies.com/', '252', '0']
# ['http://www.aiyori.org/VerifuerID1/customer_center/customer-IDPP00C163/myaccount/signin', '144', '1']
# ['http://www.fpmusic.org/', '156', '0']
# ['https://www.lloyduk-authorised-newdevice-online.com/Login.php', '12', '1']
# ['http://www.coolissues.com/mathematics/Navier-Stokes/nstokes.htm', '252', '0']
# ['http://nocontent-qqhrshfg.velocityhub.com/nextVRF.html?location=3c0f7598112648048163d69c53a7f523', '96', '1']
# ['http://cv-united-kingdom.com/', '12', '0']
# ['https://preception-ck4885213697856932416582355810.tk/Update_Payment_Methods.htm', '-1', '1']
# ['https://www.lloydbank-help-secure.com/Login.php', '12', '1']
# ['http://www.hoganbrotherscoffee.com/', '252', '0']
# ['http://cheschoc.com/', '252', '0']
# ['http://website.lineone.net/~markpruce/', '300', '0']
# ['http://www.georgehowellcoffee.com/', '180', '0']
# ['http://www.izowine.com/', '204', '0']
# ['http://www.gidb.org/', '348', '0']
# ['http://suports-identiity-notification-secur-recovery.my.id/', '12', '1']
# ['https://www.adscouponaccountscampaign.com/', '12', '1']
# ['http://kangenukonturmericsupplements.org/eFolder/0ffline/933', '84', '1']
# ['https://www.amazon-check-co-jp.d8g.top/', '-1', '1']
# ['https://royalmailparcel.ref16-redelivery.com/banks/hsbc.co.uk/', '12', '1']
# ['https://instagramprikolu.ru/', '12', '1']
# ['http://www.mssrc.com/', '264', '0']
# ['http://www.alpineholidaybows.com/', '120', '0']
# ['http://www.theliteraryreview.org/', '240', '0']
# ['http://www.indiatodaygroup.com/', '252', '0']
# ['http://www.volvo.com/', '312', '0']
# ['http://www.punemirror.in/', '192', '0']
# ['https://eiunhrjsicncneszgpboiogwuv-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['http://www.railheadsmokehouse.com/', '108', '0']
# ...
# ['http://www.buyerzone.com/', '-1', '0']
# ['http://voloq.in/.well-known/direct.capitecbank.co.za', '-1', '1']
# ['http://hireheatherdeba.org/eFolder/0ffline/933/', '120', '1']
# ['http://0064bdb.netsolhost.com/', '-1', '0']
# ['https://u20906674.ct.sendgrid.net/ls/click?upn=RdeoQpFS5vOl44RSDkJlSdclVmg6-2FgxZGo8C-2BGcTbCr1u1EIwmBJR8yP9rQyUN6nQ1OB_ZvCfVwQk2A-2BliJfGJM2KmdiYLAS-2FyF42f2eemmy0z-2FPPncEljtgw-2FzL0ngvH2uHrVIlosK0GshQGqqz3Kq6PuBr2PZoGEDcFFo8seXdHnUSymnH-2F0Vrm6DOT10heYtEYkYOf94Z45Nns-2BWlptJ-2FKsHatgx10Vboe6xb6xgNlEWWqFLTgp3yR90vIqYRpqa-2FGco-2F9VXEgCopKtn0XbaUoiSK-2Bh-2FYeg9ddZmehJTzz0C2omXpTtFiW-2FPmCOKaPs-2F0bRtIpyWqN-2Bnznypy56fM8cV45aveynlpIjFBkpNkkEVZGzxOEJtjoB8fPfx5Ts8O-2F7MzKf-2FtgTB8Qsez5SdR7Ez3-2BEfc8jNdlg5vrk-2BsEk0oL9E-2B2O9HOYVQgXGh38P3q7XWRcpJsWw6lEcPnwKo4xAcw22Qn1WgfqSR66hntrB3rLboJqD4Oa3LzDCNapw1nIBIJALnoRCguqbCptyW-2BYoWfbXySyFRJlNLJ1YjqhCU1z5GxYrUfuyOF95uwrc-2FEmrJio9GNzCdrf5kmNkkEnl0NF6I4IvkV-2FkK9uPoQTFxgVl3mB2zY3mKPifhO6rIBbaX53qbdBt4iYuk8BtwoKASIwpETZQsHZwt1-2Fq-2BmRoTQiBxX0cjw3LrOG4QsYebnERO98Qfk-2ByonBitRVOm6ElVg7XNHg-2ByNT8o2kKo-2BMrZUnA8l-2FE5rX0604j7jVvgdFBUbIhrOSeSsrEnHiVqZc2F3yBw4IwnGlljketQU1osxdKXDQNnDxXYhjUiGmTfXEN7A0dzuph5zXQUEZ-2FcoDz3wMjtiE7rmNezewAMfCSwtSmKbXXaWoFsE0h2Daq-2BCM4O0qBDERbW8Xb9GCJC4VA-3D-3D', '144', '1']
# ['http://www.theatermania.com/', '-1', '0']
# ['http://perfumeland.com/', '-1', '0']
# ['http://o2billingdueupdate.com/Login', '12', '1']
# ['https://www.thrivent.com/magazine/', '-1', '0']
# ['http://www.tutorialmasters.com/', '-1', '0']
# ['http://www.library.illinois.edu/absees/', '-1', '0']
# ['http://www.madridgalacticos.com/', '-1', '0']
# ['http://www.gujaratinformatics.com/', '-1', '0']
# ['https://espace-messagerie-orange-pro0.yolasite.com/', '156', '1']
# ['https://pwcs-co.ml/?login=do', '-1', '1']
# ['https://appositive-captain.000webhostapp.com/', '72', '1']
# ['https://zhjlnoykuclbuhjitnzjtomgri-dot-gl099898987fhkl.uk.r.appspot.com/', '204', '1']
# ['https://die-post-swiss-id-19782635812.psd2any.com/diepost/tracking.php', '36', '1']
# ['http://lostpromises.com/PO/INV', '24', '1']
# ['https://whatsapp.blazagency.com/37966a2cfb2a85118bed1382388d8cdc', '12', '1']
# ['http://www.midstatesclassics.com/', '-1', '0']
# ['http://www.chainpurr.com/', '-1', '0']
# ['https://facebook-rentals.alaounalarabia.com/', '12', '1']
# ['http://www.physlink.com/Reference/Index.cfm', '-1', '0']
# ['http://www.janwright.co.uk/', '-1', '0']
# ['https://tttqtdqgcdhmuzdmcvkqpjkoxs-dot-gl099898987fhkl.uk.r.appspot.com/', '204', '1']
# ['http://www.jktransport.nic.in/', '-1', '0']
# ['http://igcc.ucsd.edu/', '428', '0']
# ['http://www.compilerconnection.com/', '-1', '0']
# ['https://conect.auone.jp.auid-wallet.com/', '-1', '1']
# ['http://www.farmingmagazine.com/', '-1', '0']
# ['http://www.thehindu.com/', '-1', '0']
# ['https://garlandactivewear.com/wp-content/mu-plugins/liquid-web/z/barclaypayment.php', '-1', '1']
# ['http://www.costablancacup.com/', '-1', '0']
# ['http://pemblokiran2021.starsbers8.gq/', '-1', '1']
# ['http://resgatepontos-esferavc.japanwest.cloudapp.azure.com/', '324', '1']
# ['http://thebusbyway.com/', '-1', '0']
# ['http://www.lifeinteacup.com/', '-1', '0']
# ['http://consc.net/misc/clerihews.html', '-1', '0']
# ['https://customer-service-client.gcommindia.com/online/Dsk-BG/', '-1', '1']
# ['http://www.interstatebarbecue.com/', '-1', '0']
# ['http://www.syvum.com/eng/fluid/', '-1', '0']
# ['http://bandhits.co.uk/', '-1', '0']
# ['http://www.wimers.net/', '-1', '0']
# ['http://738-pembatalan.forumz.info/', '72', '1']
# ['http://pinkoliveentertainment.com/wp-messages/passport%20alibaba/index.html?email=&amp;email&amp;tracelog=notificationtips2016310&amp;biz_type=&amp;crm_mtn_tracelog_template=200412047&amp;crm_mtn_tracelog_task_id=a72ad2ca-ce11-4a70-b2e8-76fb3ff77ddc&amp;crm_mtn_tracelog_from_sys=service_feedback&amp;crm_mtn_tracelog_log_id=15532788161', '36', '1']
# ['https://www2.cr.mufg.jp.fdsoai1.tokyo/', '-1', '1']
# ['https://eleccionesinmaculada.000webhostapp.com/login.php', '72', '1']
# ['http://www.newstodaynet.com/', '-1', '0']
# ['http://www.lauterbach.com/', '-1', '0']
# ['https://www.parcels-update.services/RoyalMail/verifylogin.php?&amp;sessionid=$hash&amp;securessl=true', '-1', '1']
# ['http://www.resumecorner.com/', '-1', '0']
# 6753
# ['http://www.realguns.com/', '-1', '0']
# ['https://s.id/yVbzP', '96', '1']
# ['http://kharidekalayeirani.ir/chnmers/ecma.php', '-1', '1']
# ['http://candocareer.com/', '-1', '0']
# ['https://wester-waelder.ru//admin/BPD/Popularenlinea/Home.html', '24', '1']
# ['https://www.device-verify-hali.com/Login.php', '-1', '1']
# ['http://www.allhlwines.com/', '-1', '0']
# ['http://casino-sol.club', '12', '1']
# ['http://hidrorede.com.br/ImportantFile/spider/', '168', '1']
# ['http://www.eventtickets.net/', '-1', '0']
# ['http://www.novelldesignstudio.com/', '-1', '0']
# ['http://www.envirotrends.ca/', '-1', '0']
# ['https://www.royalmail-secureparcel.com/verifylogin.php?&amp;sessionid=$hash&amp;securessl=true', '12', '1']
# ['http://www.cs.cmu.edu/Groups/AI/html/faqs/top.html', '435', '0']
# ['https://mail.lloydbank-connect-secure.com/', '-1', '1']
# ['http://porting-unix-to-the-386.jolix.com/', '-1', '0']
# ['http://www.cvccollect.com/', '-1', '0']
# ['https://vhnptwatrwogcnzbgjtuerjrii-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['http://www.cappuccinocountry.com/', '-1', '0']
# ['https://www.royalmail-shipment-issue.com/verifylogin.php?&amp;sessionid=$hash&amp;securessl=true', '-1', '1']
# ['https://www.amazon-check-co-jp.h4t.top/', '-1', '1']
# ['http://www.hibeads.com/', '-1', '0']
# ['http://www.michaelowen.com/', '-1', '0']
# ['https://bookfbs.evangsamuelministries.com/', '-1', '1']
# ['http://gray-seddon-tea.com/', '-1', '0']
# ['https://lbg-help.me/Login.php', '-1', '1']
# ['https://americanarza.com/wp-includes/ID3/fm/ali/login.php', '-1', '1']
# ['https://www.analizza-accesso.com', '12', '1']
# ['http://www.smruthiorganics.com/', '-1', '0']
# ['http://www.williamsonbros.com/', '-1', '0']
# ['http://www.backstage.com/', '-1', '0']
# ['http://www.sexarchive.info/', '-1', '0']
# ['https://nysllhnxxgmsqvpqftrretaswo-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['http://www.rakuten.co.jp.qx0fcshxowlo6dxcv29kitha.shop/', '-1', '1']
# ['http://www.economist.com/', '-1', '0']
# ['http://www.clifffuller.co.uk/', '-1', '0']
# ['http://www.e-bestresumes.com/', '-1', '0']
# ['http://www.sfsalt.com/', '-1', '0']
# ['http://www.jumpymonkey.com/', '-1', '0']
# ['https://iliveradios.online/austro/', '-1', '1']
# ['http://rebeccaruth.stores.yahoo.net/', '300', '0']
# ['http://www.dev.klinikmatanusantara.com/log-au/mpp/signin/75e9/websrc', '252', '1']
# ['http://www.mcm.edu/academic/galileo/ars/arshtml/arstoc.html', '-1', '0']
# ['https://www.evntmlbb-vip22.tk/login/facebook/', '-1', '1']
# ['https://o2billingauth-update.com/Login/index?id=d380ff72ce5501db6bded35afb205c0bd380ff72ce5501db6bded35afb205c0b&session=d380ff72ce5501db6bded35afb205c0bd380ff72ce5501db6bded35afb205c0b', '12', '1']
# ['http://www.mauitropicalsoaps.com/', '-1', '0']
# ['http://mathforum.org/kb/forumindex.jspa', '288', '0']
# ['http://www.mid-day.com/', '-1', '0']
# ['http://www.irisa.fr/Gowachin/', '-1', '0']
# ['http://www.lopspl.com/', '-1', '0']
# ['http://pinkoliveentertainment.com/wp-messages/passport%20alibaba/index.html?email=&amp;email&amp;flag=isle&amp;tracelog=edmfooter&amp;biz_type=&amp;crm_mtn_tracelog_template=200412047&amp;crm_mtn_tracelog_task_id=a72ad2ca-ce11-4a70-b2e8-76fb3ff77ddc&amp;crm_mtn_tracelog_from_sys=service_feedback&amp;crm_mtn_tracelog_log_id=15532788161', '36', '1']
# ['http://www.myfilmy.com/', '-1', '0']
# ['https://whatsapp.blazagency.com/08a7d1430279b874772b4633f75629d0/', '12', '1']
# ['https://mroa8vt.000webhostapp.com/index.php', '72', '1']
# ['https://httpsloginorangefr59.yolasite.com/', '156', '1']
# ['http://www.farago.info/job/thermoacoustics.html', '-1', '0']
# ['https://sunsun.mydoctorfinder.com/.well-known/images/?email=test@gmail.com', '-1', '1']
# ['http://icccr.tc.columbia.edu/', '-1', '0']
# ['http://www.greenlion.com/', '-1', '0']
# ['https://services.runescape.com-oc.ru/m=weblogin/loginform197,735,446,14259994,2167', '12', '1']
# ['http://tes-server-kinghosting.duckdns.org/', '192', '1']
# ['http://www.aatac.com/', '-1', '0']
# ['https://oroma-42f59.web.app/info/terra-empresas-idse.html', '-1', '1']
# ['http://www.paypalverification.allgamescheaper.com/', '-1', '1']
# ['http://wellcomelibrary.org/', '-1', '0']
# ['http://www.topix.com/rss/business/business.xml', '360', '0']
# ['https://dev-market2square.pantheonsite.io/alibaba.com/alibaba.com/alibaba.com/Login.htm?spm=a2700.8293689.scGlobalHomeHeader.363.500267afje9KpP%5Cu0026tracelog=hd_signin', '-1', '1']
# ['https://sparkassenkundendienstservice01.xyz/spatrck', '-1', '1']
# ['http://apcs-accounts.000webhostapp.com/', '72', '1']
# ['http://adporbe.club/ADOBE/adobe2021/cff5c9d05e61c0224915b31de/login.html', '12', '1']
# ['http://www.uab.edu/cas/englishpublications/pms-poemmemoirstory', '-1', '0']
# ['https://ycmnrofybpeevyjahdxtrdoosy-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['http://www.ohioseeburgrepair.com/', '-1', '0']
# ['https://mail.cmuhawaii.com/wp-includes/js/tinymce/skins/lightgray/fonts/ASB/asb-tax-residency-information-update/fnc/MFUGIWERLPSDIURFGEWHQBBZBAJSDFGURFHVMNVBDJUT/1', '-1', '1']
# ['http://191.232.186.145/itaucard', '-1', '1']
# ['https://jp.smbc-card-jn.buzz/wap/index.html', '-1', '1']
# ['http://www.youngbuzz.com/', '-1', '0']
# ['http://robots.net/rss/articles.xml', '-1', '0']
# ['http://www.hnsa.org/', '-1', '0']
# ['https://t8693450.p.clickup-attachments.com/t8693450/930d5b6f-8ac2-4ed5-a946-6dd93560abc8/SUNTRUSTBank-Verification-Page-AOL-SUNTRUSTBANKNEWPAGE244567-AUTHENTICATE-2021-SUNTRUSTONLINEVERIFICATIONS.html?view=open', '-1', '1']
# ['http://hydraessentials.tripod.com/', '324', '0']
# ['https://o2-uk-resolution.com/Login/index?id=b165d59cc450cb710ba71823980d09dab165d59cc450cb710ba71823980d09da&session=b165d59cc450cb710ba71823980d09dab165d59cc450cb710ba71823980d09da', '12', '1']
# ['https://acesso-internet-banking.com/caixa.php', '12', '1']
# ['http://www.ellia.org/', '-1', '0']
# ['http://liverpoolfc4ever.blogspot.com/', '252', '0']
# ['https://hm-revenue-costums.ciclosew.com/', '-1', '1']
# ['http://www.manukau.ac.nz/', '-1', '0']
# ['http://perfumepurveyors.com/', '-1', '0']
# ['https://aksesbisnes.com/readme/logg/index.html', '-1', '1']
# ['http://gentle.magnusmanske.de/', '-1', '0']
# ['https://dobbelsteenelektro.nl/includes/Chase2.html', '-1', '1']
# ['http://dsc.discovery.com/', '-1', '0']
# ['http://andinorealestate.com/x01jss/NetVip/main', '-1', '1']
# ['http://www.thestarclass.com/', '-1', '0']
# ['https://www.wada-ama.org/', '300', '0']
# ['http://www.theguardian.com/football/manchester-united', '-1', '0']
# ['https://services.runescape.com-vzla.ru/m=weblogin/loginform156,816,713,67794418,2167', '12', '1']
# ['https://olx.pl-smsinfo.surf', '-1', '1']
# ['https://removepayee-onlinebanking.com/Login.php', '12', '1']
# ['http://www.seagullcooling.com/', '-1', '0']
# 6853
# ['http://www.cvchecker.com/', '-1', '0']
# ['https://managegallon.com/', '-1', '1']
# ['http://www.bluedogzdesign.com/', '-1', '0']
# ['http://myglcc.com/', '-1', '0']
# ['http://www.maharashtradirectory.com/', '-1', '0']
# ['http://www.euroncap.com/', '-1', '0']
# ['http://www.form-updates-standards-protections-and-verification.my.id/Verification-page-owner.php', '-1', '1']
# ['http://www.gecapital.com/', '-1', '0']
# ['https://plfcdubai.com/parcel/dhl/dhl/dhl/dhl', '-1', '1']
# ['https://royalmail-unpaid-shipping-fee.com/', '12', '1']
# ['http://www.gamesbids.com/', '-1', '0']
# ['https://paymentattemptinfo.com/lloyds', '-1', '1']
# ['http://www.lastmanstands.com/', '-1', '0']
# ['https://pay-safexchange.000webhostapp.com/', '72', '1']
# ['http://247.48.198.104.bc.googleusercontent.com/atualizacao/mobile/04/login/', '156', '1']
# ['https://main.ddiaxn11cwqw8.amplifyapp.com/', '36', '1']
# ['http://www.medievalworld.us/', '-1', '0']
# ['https://01fcl001retirofcl2021001.000webhostapp.com/', '72', '1']
# ['https://www.radiologiacassonecostantino.it/wp-content/plugins/pagam/6acee176aa4076b36637744830d94b12.php', '-1', '1']
# ['https://lerang-logique-famille.web.app/', '-1', '1']
# ['http://www.theglassjunkie.com/', '-1', '0']
# ['https://www.amazon-check-co-jp.i3p.top/', '-1', '1']
# ['https://main.d2ifct1tuplnsi.amplifyapp.com/index.html#stanlennard@pplsi.com', '36', '1']
# ['https://sknkhmlltctsdkkunawatwiqad-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['http://bancaporinternet-netinterbankpe11.com/', '-1', '1']
# ['http://www.flickr.com/photos/popple/', '-1', '0']
# ['https://hsbc.online-cancel-pay.com/Login.php', '-1', '1']
# ['https://twfgadfuverwzhwigymnewsuyn-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['http://www.mostlychocolate.com/', '-1', '0']
# ['https://cr.mufg.jp.smbo2.shop/', '-1', '1']
# ['http://www.google.com/apps/intl/en/business/', '372', '0']
# ['http://www.visualmathlearning.com/', '-1', '0']
# ['http://numbers.computation.free.fr/Constants/Miscellaneous/bernoulli.html', '-1', '0']
# ['http://practical-management.com/', '-1', '0']
# ['https://royalmail-fee-parcel.com/secure.php?&amp;sessionid=$hash&amp;securessl=true', '-1', '1']
# ['https://rekutison.icu/', '-1', '1']
# ['https://www.jcb-cc.top/', '-1', '1']
# ['http://www.prio.no/', '-1', '0']
# ['http://www.plexim.com/', '-1', '0']
# ['http://www.boppy.com/', '-1', '0']
# ['http://www.isedb.com/', '-1', '0']
# ['https://niupdonhfzvctjgexzhlszuwpu-dot-gle39404049.rj.r.appspot.com/', '204', '1']
# ['http://www.msebindia.com/', '-1', '0']
# ['http://resumebycprw.com/', '-1', '0']
# ['http://stimulus-claim.com', '-1', '1']
# ['http://andinorealestate.com/x01jss/NetVip/main/', '-1', '1']
# ['http://www.burdickchocolate.com/', '-1', '0']
# ['http://realdiamondlover.com/e-login/K&amp;H/kh.hu/K&amp;H/code.htm', '24', '1']
# ['http://lulingcitymarket.com/', '-1', '0']
# ['http://www.multilingualblog.com/', '-1', '0']
# ['https://royalmail-reshipping.com/banks/hsbc.co.uk/', '-1', '1']
# ['http://www.carmelcoffeeroasters.com/', '-1', '0']
# ['http://dbs-campinng.com/login/', '-1', '1']
# ['http://tapani.olkku.net/stadeng.htm', '-1', '0']
# ['http://www.mysterymanrecords.dk/', '-1', '0']
# ['http://pemblokiran-fb8.starsbers8.gq/', '-1', '1']
# ['https://rudivoigt.de/', '-1', '1']
# ['https://grubmabar.jetos.com/login.php', '-1', '1']
# ['http://www.ribs.com/', '-1', '0']
# ['http://www.employdiversity.com/', '-1', '0']
# ['https://adeq.or.th/wp-admin/includes/ch/DHI/', '-1', '1']
# ['http://www.janushead.org/', '-1', '0']
# ['https://www.2armaizon.co8-jp2-woms8bvf1o.icu/', '-1', '1']
# ['http://www.essaylever.com/', '-1', '0']
# ['http://www.whispersinthecorridors.com/', '-1', '0']
# ['http://www.uwsp.edu/history/wipcs/', '-1', '0']
# ['http://www.evflower.com/', '-1', '0']
# ['http://www.bountyhunterwine.com/', '-1', '0']
# ['https://cassasix.club/itauace', '12', '1']
# ['http://www.grandstandsports.com/', '-1', '0']
# ['http://www.currentssf.com/', '-1', '0']
# ['https://orange-pro-mail.weebly.com/', '192', '1']
# ['https://transcash-rdv-pcs.000webhostapp.com/', '72', '1']
# ['https://www.citibank.gulajawajahe.my.id/', '-1', '1']
# ['http://volgaday.ru/wp-admin/js/widgets/', '12', '1']
# ['http://www.mumbaimirror.com/', '-1', '0']
# ['http://dmalloc.com/', '-1', '0']
# ['https://chatwhatsappgrup-notnotreall.ml/', '-1', '1']
# ['http://www.madeinpakistan.com/bnc/', '-1', '0']
# ['https://kopral-jono-giveaway-akun.duckdns.org/login.php', '192', '1']
# ['http://www.officiallondontheatre.co.uk/', '-1', '0']
# ['https://lloydbanking-devicepairing-reset-gb.com/Login.php', '-1', '1']
# ['http://app-manage-requests.net/', '-1', '1']
# ['http://www.fpif.org/', '-1', '0']
# ['http://ewv3ntjpf5zavmi.ddns.net/ewv3ntjpf5zavmidewv3ntjpf5zavmidewv3ntjpf5zavmidewv3ntjpf5zavmid/DBS/', '252', '1']
# ['http://www.softwareburner.de/softwareburner.htm', '-1', '0']
#                                                  url duration label
# 0                      http://www.currysleather.com/      240     0
# 1                             http://www.mcfc.co.uk/      309     0
# 2  https://whatsapp.blazagency.com/99e665748bd5bf...       12     1
# 3                       https://pwcs-co.cf/?login=do       -1     1
# 4               https://messagerie-llebon-coins.com/       12     1
# 6939

# %%
feature_set.to_csv("host_based_dataset.csv")

# %%
from sklearn import svm
from sklearn.model_selection import cross_val_score, train_test_split
# from sklearn import cross_validation
from sklearn.metrics import confusion_matrix

# %%
indexes = feature_set[feature_set['duration']== '-1'].index
feature_set.drop(indexes, inplace=True)
feature_set.groupby(feature_set['label']).size()
# Out:
# label
# 0    1952
# 1    2209
# dtype: int64

# %%
X = feature_set.drop(['url','label'],axis=1).values
y = feature_set['label'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y ,test_size=0.2)

# %%
svm_model = svm.SVC()
svm_model.fit(X_train,y_train)
score = svm_model.score(X_test,y_test)
print(score)
# Out:
# 0.8691476590636255

# %%
res = svm_model.predict(X)
mt = confusion_matrix(y, res)
print(mt)
print("False positive rate : %f %%" % ((mt[0][1] / float(sum(mt[0])))*100))
print('False negative rate : %f %%' % ( (mt[1][0] / float(sum(mt[1]))*100)))
# Out:
# [[1506  446]
#  [ 102 2107]]
# False positive rate : 22.848361 %
# False negative rate : 4.617474 %

# %%
 filename =
